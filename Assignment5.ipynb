# %% [markdown]
# <a href="https://colab.research.google.com/github/mithra-malicious/carisurg_portfolio/blob/main/Day5_WriteUp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Q: What other Metric is not being considered and what is the significance? **

# %% [markdown]
# A: While the pipeline successfully normalizes vital signs like temperature and blood pressure, it completely omits several critical qualitative and contextual metrics that are essential for accurate emergency triage. The current model fails to capture the patient’s chief complaint, symptom duration, or localized pain scores, which frequently dictate clinical urgency more than stable vital signs alone. Furthermore, the dataset completely lacks critical baseline context such as pre-existing chronic conditions, active medication lists, and demographic age vulnerabilities that heavily influence acute disease progression. By ignoring these subjective and structural clinical dimensions, any downstream predictive model risks misclassifying a high-acuity patient who presents with normal vitals but possesses a life-threatening chief complaint.
